# %%
import numpy as np

from students.bolshanin.lesson1 import Exercise as bolshanin  # noqa: F401
from students.razin.lesson1 import Exercise as razin  # noqa: F401
from students.staritsyn.lesson1 import Exercise as staritsyn  # noqa: F401

# %load_ext autoreload
# %autoreload 2

# %%
n = 10
rng = np.random.default_rng(0)
A = rng.random((n, n), dtype=np.float32)
x = rng.random(n, dtype=np.float32)
b = A @ x
x

# %%
# %timeit bolshanin.solve(A, b)

# %%
# %timeit staritsyn.solve(A, b)

# %%
# %timeit razin.solve(A, b)
